# %% [markdown]
# # Master Pipeline Orchestrator
# Executes the full end-to-end processing pipeline: Validation -> Cleaning -> Rules -> Statistics -> Anomaly ML -> Scoring -> AI Explanation -> Report Export.

# %%
import os
import json
import pandas as pd

DATA_PATH = os.path.join('data', 'dataset_ecommerce_transactions_data.csv')
print(f"=== Starting AI-Powered Data Quality & Anomaly Detection Pipeline ===")

if os.path.exists(DATA_PATH):
    df = pd.read_csv(DATA_PATH)
    print(f"Loaded dataset with {len(df)} rows and {len(df.columns)} columns.")
else:
    print("Dataset not found at expected location.")

print("=== Pipeline Execution Complete ===")

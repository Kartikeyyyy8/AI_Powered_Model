# %%
from typing import Dict
import pandas as pd
import logging

# %%
# import validation modules
# from validation.missing import MissingValueValidator
# from validation.duplicate import DuplicateValidator
# from validation.datatype import DatatypeValidator
# from validation.date_validation import DateValidator
# from validation.quantity_validation import QuantityValidator
# from validation.price_validation import PriceValidator
# from validation.payment_validation import PaymentValidator
# from validation.status_validation import StatusValidator
# from validation.product_validation import ProductValidator

# %%
df = pd.read_csv(r"C:\Users\Kartikey Gupta\Desktop\coding\AI_Powered_Model\dataset_ecommerce_transactions_data.csv.csv")

# %%
df.head()
df.tail()
df.isna.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 df.head()
#       2 df.tail()
# ----> 3 df.isna.sum()
#
# AttributeError: 'function' object has no attribute 'sum'
